# %%
import numpy as np
import pandas as pd

import folium
from streamlit_folium import folium_static
import geohash

# pip install networkx

# %%
def geohash_encode(lat, lon, level=10):
    if (lat is None) or (lon is None):
        return None
    elif np.isnan(lat) or np.isnan(lon):
        return None
    else:
        return geohash.encode(lat, lon, level)

# %%
df = pd.DataFrame(
    np.random.rand(50, 2) / [80, 80] + [36.95, 138.78],
    columns=["lat", "lon"]
)

# %%
df
# Out:
#           lat         lon
# 0   36.952840  138.790550
# 1   36.952709  138.790484
# 2   36.960886  138.780211
# 3   36.956232  138.786653
# 4   36.950209  138.790135
# 5   36.960095  138.787453
# 6   36.957826  138.783232
# 7   36.958884  138.781824
# 8   36.958648  138.783984
# 9   36.959343  138.780039
# 10  36.950109  138.784367
# 11  36.958808  138.780909
# 12  36.959129  138.780572
# 13  36.953822  138.786000
# 14  36.955502  138.788306
# 15  36.960202  138.781493
# 16  36.957458  138.783623
# 17  36.958077  138.784268
# 18  36.953129  138.789135
# 19  36.953804  138.788835
# 20  36.952559  138.792328
# 21  36.951926  138.788007
# 22  36.956409  138.783474
# 23  36.958793  138.790066
# 24  36.959451  138.787005
# 25  36.956221  138.784985
# 26  36.956980  138.788392
# 27  36.957516  138.788148
# 28  36.953504  138.788790
# 29  36.951770  138.791740
# 30  36.955830  138.787983
# 31  36.952648  138.788299
# 32  36.958162  138.790709
# 33  36.955067  138.783421
# ...

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit-card
# Out:
# ...
#      ---------------------------------------- 0.0/679.4 kB ? eta -:--:--
#      -------- ----------------------------- 143.4/679.4 kB 2.8 MB/s eta 0:00:01
#      ------------------ ------------------- 337.9/679.4 kB 3.5 MB/s eta 0:00:01
#      ----------------------------- -------- 522.2/679.4 kB 3.7 MB/s eta 0:00:01
#      -------------------------------------- 679.4/679.4 kB 3.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
